# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# # Creating dataset

# %%
from sklearn.datasets import make_circles

# %%
n_samples = 1000

X, y = make_circles(n_samples, noise=0.03, random_state=42)
# X : x, y coordinates of points
# y : labels (0, 1)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.show()

# %% [markdown]
# # Input, output shapes

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X_train, X_test = X[:800], X[800:]
y_train, y_test = y[:800], y[800:]

# %%
X_train.shape, X_test.shape
# Out:
# ((800, 2), (200, 2))

# %% [markdown]
# # Creating the model

# %%
tf.random.set_seed(42)

# %%
classifier = tf.keras.Sequential(
    [
        tf.keras.layers.InputLayer(2),
        tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
        tf.keras.layers.Dense(4, activation=tf.keras.activations.relu),
        tf.keras.layers.Dense(1, activation=tf.keras.activations.sigmoid)
    ]
)

# %%
classifier.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(lr=0.02),
    metrics = ['accuracy']
)

# %%
# Learning rate callback
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch, lr: lr)

# %%
history = classifier.fit(X_train, y_train, epochs=100, verbose=1, callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.4725
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6853 - accuracy: 0.5362
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5462
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6557 - accuracy: 0.6438
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6122 - accuracy: 0.6787
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5146 - accuracy: 0.8850
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4161 - accuracy: 0.9050
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.9563
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9837
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9862
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9925
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9937
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 0.9937
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9975
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9975
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9975
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9975
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9975
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9900
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9937
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9987
# Epoch 22/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9950
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9925
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9925
# Epoch 25/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9950
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9975
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9937
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9962
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9912
# Epoch 30/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9987
# Epoch 31/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9975
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9912
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9887
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 0.9950
# Epoch 35/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 0.9962
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9962
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9950
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9962
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9962
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9950
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9950
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9900
# Epoch 43/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 0.9950
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9962
# Epoch 45/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0201 - accuracy: 0.9975
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9925
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9937
# Epoch 48/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 0.9950
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9950
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9937
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.9937
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9950
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9975
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9950
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9987
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9975
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9950
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9912
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9900
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9950
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9812
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9912
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9975
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9975
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9925
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9975
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 0.9975
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9912
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9925
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9925
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9987
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9950
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9987
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9950
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9925
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9987
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9975
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9962
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9950
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9987
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9975
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9962
# Epoch 83/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 0.9912
# Epoch 84/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 0.9937
# Epoch 85/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9962
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9950
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9950
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9925
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9950
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9975
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9950
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 0.9975
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9937
# Epoch 96/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9887
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9987
# Epoch 99/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9950

# %%
classifier.predict([[0, 0]])
# Out:
# array([[1.]], dtype=float32)

# %%
classifier.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9950
# [0.017404938116669655, 0.9950000047683716]

# %%
pd.DataFrame(history.history)
# Out:
#         loss  accuracy    lr
# 0   0.693613   0.47250  0.02
# 1   0.685296   0.53625  0.02
# 2   0.676521   0.54625  0.02
# 3   0.655680   0.64375  0.02
# 4   0.612152   0.67875  0.02
# ..       ...       ...   ...
# 95  0.034008   0.98875  0.02
# 96  0.008827   1.00000  0.02
# 97  0.007576   0.99875  0.02
# 98  0.009746   0.99750  0.02
# 99  0.019750   0.99500  0.02
#
# [100 rows x 3 columns]

# %%
pd.DataFrame(history.history).plot(figsize=(10, 7), xlabel='epoch')
plt.show()

# %%
plt.plot(history.epoch, history.history['loss'], 'ro:', label='Loss')
plt.plot(history.epoch, history.history['accuracy'], 'bo:', label='Accuracy')
plt.plot(history.epoch, history.history['lr'], 'go:', label='Learning rate')
plt.grid()
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
lrs =  1e-4 * 10**(tf.range(100)/20)

fig = plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history['loss'])
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.title('Learning rate vs. Loss')
plt.show()

# %%
def plot_decision_boundary(model, X, y):
    """
    Plots the decision boundary created by a model predicting on X.
    This function was inspired by two resources:
    1. https://cs231n.github.io/neural-networks-case-study/
    2. https://github.com/madewithml/basics/blob/master/notebooks/09_Multilayer_Perceptrons/09_TF_Multilayer_Perceptrons.ipynb 
    """
    
    steps = 100

    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, steps),
                        np.linspace(y_min, y_max, steps))
    
    # Create X value (we're going to make predictions on these)
    x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together

    # Make predictions
    y_pred = model.predict(x_in)

    # Check for multi-class
    if len(y_pred[0]) > 1:
        print("doing multiclass classification")
        # We have to reshape our prediction to get them ready for plotting
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("doing binary classification")
        y_pred = np.round(y_pred).reshape(xx.shape)
    
    # Plot the decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
fig = plt.figure(figsize=(15, 8))

plt.subplot(1, 2, 1)
plt.title('Training Data')
plot_decision_boundary(classifier, X_train, y_train)

plt.subplot(1, 2, 2)
plt.title('Testing Data')
plot_decision_boundary(classifier, X_test, y_test)

plt.show()
# Out:
# doing binary classification
# doing binary classification
